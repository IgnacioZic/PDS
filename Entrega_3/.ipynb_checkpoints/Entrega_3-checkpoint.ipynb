# %% [markdown]
# # Entrega 3
# ### Ignacio Ziccardi
# ### Simulación de un ADC (cuantización)

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 23 09:26:57 2025

@author: Ignacio
"""
import numpy as np
import matplotlib.pyplot as plt

# %%
#%%  Valores de parámetros
Fo = 1.0
Fs = 1000.0 # frecuencia de muestreo (Hz)
N = 1000   # cantidad de muestras
ts = 1/Fs # tiempo de muestreo
df = Fs/N # resolución espectral
Ac =2**0.5 #Amplitud 
DC = 0 #Valor Contínua
tita = 0 #Defasaje
SNR = 97 # SNR en dB
sigma = (10**(-SNR/10)) #Varianza
desvio = sigma**0.5 #Desvío Estándar
B = 16 #Número de Bits
fc = 0.8 #Factor de Carga para no tener saturación del ADC por ruido en el pico de la señal
Vref = 2#Ac/fc #Tensión de referencia del ADC
#q = Vref/(2**(B-1))

# %%
#%% Funciones
def my_sin_gen( vmax, dc, fo, ph, nn, fs): 
    tt = np.arange(0,nn*1/fs,1/fs) # grilla de sampleo temporal
    xx = vmax*np.sin(2*np.pi*fo*tt + ph) + dc #Senoidal
    return [tt, xx]

def cuantificar(signal, bits, vref):
    q = vref/(2**(bits-1)) 
    #s1 = (fc*Vref/Ac)*signal
    sq = signal*(1/q)
    sq1 = np.round(sq)
    ss_cuantizada = sq1*q#*(1/(fc*Vref/Ac))
    return ss_cuantizada

# %%
#%%Obtengo señal con ruido y su versión cuantizada 
tt, s = my_sin_gen(vmax = Ac, dc = DC, fo = Fo, ph=tita, nn = N, fs = Fs )
#Genero señal aleatoria para el ruido
na=np.random.normal(0, desvio, len(tt))

ss = s + na

ssq = cuantificar(signal = ss,bits = B,vref = Vref)#4Bits

plt.figure("Señal original",figsize=(10, 5))
plt.plot(tt, ss, label="Señal analógica")
plt.title("Señal original")
plt.xlabel("Tiempo (s)",figsize=(10, 5))
plt.ylabel("Amplitud")
plt.show()
plt.figure("Cuantizada")
plt.plot(tt, ssq, color = 'r', label=f"Señal cuantizada con B = {B}", marker=".")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 13
#      11 plt.plot(tt, ss, label="Señal analógica")
#      12 plt.title("Señal original")
# ---> 13 plt.xlabel("Tiempo (s)",figsize=(10, 5))
#      14 plt.ylabel("Amplitud")
#      15 plt.legend()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\pyplot.py:4396, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4387 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4388 def xlabel(
#    4389     xlabel: str,
#    (...)
#    4394     **kwargs,
#    4395 ) -> Text:
# -> 4396     return gca().set_xlabel(
#    4397         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4398     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_base.py:3629, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3622     x = {
#    3623         'left': 0,
#    3624         'center': 0.5,
#    3625         'right': 1,
#    3626     }[loc]
#    3627     kwargs.update(x=x, horizontalalignment=loc)
# -> 3629 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axis.py:1902, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1900 if fontdict is not None:
#    1901     self.label.update(fontdict)
# -> 1902 self.label.update(kwargs)
#    1903 self.stale = True
#    1904 return self.label
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)
#    1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: 'Text' object has no property 'figsize'
